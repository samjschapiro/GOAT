# %% [markdown]
# # Load data in

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
mnist_adam_005 = pd.read_csv('logs/mnist_adam_0.05_100ep.txt')
mnist_sam_005 = pd.read_csv('logs/mnist_sam_0.05_100ep.txt')

# %%
color_adam_005 = pd.read_csv('logs/color_adam_0.05_100ep.txt')
color_sam_005 = pd.read_csv('logs/color_sam_0.05_100ep.txt')

# %%
portraits_adam_005 = pd.read_csv('logs/portraits_adam_0.05_100ep.txt')
portraits_sam_005 = pd.read_csv('logs/portraits_sam_0.05_100ep.txt')

# %%
covtype_adam_005 = pd.read_csv('logs/covtype_adam_0.05_100ep.txt')
covtype_sam_005 = pd.read_csv('logs/covtype_sam_0.05_100ep.txt')

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(12,5))
axs[0].set_title('Sharpness vs. Error')
axs[0].scatter(covtype_sam_005[' st_acc_all'], covtype_sam_005[' st_sharp_all'], label='SAM');
axs[0].scatter(covtype_adam_005[' st_acc_all'], covtype_adam_005[' st_sharp_all'], label='Adam');
axs[0].legend();
axs[1].set_title('Rep Norm vs. Error')
axs[1].scatter(covtype_sam_005[' st_acc_all'], covtype_sam_005[' rep_norm_all'], label='SAM');
axs[1].scatter(covtype_adam_005[' st_acc_all'], covtype_adam_005[' rep_norm_all'], label='Adam');
axs[1].legend();
axs[2].set_title('Rep Shift vs. Error')
axs[2].scatter(covtype_sam_005[' st_acc_all'], covtype_sam_005[' st_rep_shift_all'], label='SAM');
axs[2].scatter(covtype_adam_005[' st_acc_all'], covtype_adam_005[' st_rep_shift_all'], label='Adam');
axs[2].legend();
print('Sharpness/Error Correlation')
print('SAM', round(covtype_sam_005.corr()[' st_acc_all'].loc[' st_sharp_all'], 2))
print('Adam:', round(covtype_adam_005.corr()[' st_acc_all'].loc[' st_sharp_all'], 2))
print('Rep Norm/Error Correlation')
print('SAM', round(covtype_sam_005.corr()[' st_acc_all'].loc[' rep_norm_all'], 2))
print('Adam:', round(covtype_adam_005.corr()[' st_acc_all'].loc[' rep_norm_all'], 2))
print('Rep Shift/Error Correlation')
print('SAM', round(covtype_sam_005.corr()[' st_acc_all'].loc[' st_rep_shift_all'], 2))
print('Adam:', round(covtype_adam_005.corr()[' st_acc_all'].loc[' st_rep_shift_all'], 2), '\n')

print('Accuracy Comparison')
print('SAM:', round(np.mean(covtype_sam_005[' st_acc_all']), 2), round(np.std(covtype_sam_005[' st_acc_all']), 2), 'vs', 'Adam:',
      round(np.mean(covtype_adam_005[' st_acc_all']), 2), round(np.std(covtype_adam_005[' st_acc_all']), 2), '\n')

print('Sharpness Comparison')
print('SAM:', round(np.mean(covtype_sam_005[' st_sharp_all']), 2), 'vs', 'Adam:',
      round(np.mean(covtype_adam_005[' st_sharp_all']), 2), '\n')

print('Rep Shift Comparison')
print('SAM:', round(np.mean(covtype_sam_005[' st_rep_shift_all']), 2), 'vs', 'Adam:',
      round(np.mean(covtype_adam_005[' st_rep_shift_all']), 2), '\n')

print('Rep Norm Comparison')
print('SAM:', round(np.mean(covtype_sam_005[' rep_norm_all']), 2), 'vs', 'Adam:',
      round(np.mean(covtype_adam_005[' rep_norm_all']), 2))
# Out:
# Sharpness/Error Correlation
# SAM -0.38
# Adam: -0.24
# Rep Norm/Error Correlation
# SAM -0.82
# Adam: -0.05
# Rep Shift/Error Correlation
# SAM -0.64
# Adam: -0.09
#
# Accuracy Comparison
# SAM: 65.53 4.79 vs Adam: 64.26 3.23
#
# Sharpness Comparison
# SAM: 0.03 vs Adam: 0.17
#
# Rep Shift Comparison
# SAM: 0.16 vs Adam: 2.5
#
# Rep Norm Comparison
# SAM: 258.62 vs Adam: 222.09

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(12,5))
axs[0].set_title('Sharpness vs. Accuracy')
axs[0].scatter(mnist_sam_005[' st_acc_all'], mnist_sam_005[' st_sharp_all'], label='SAM');
axs[0].scatter(mnist_adam_005[' st_acc_all'], mnist_adam_005[' st_sharp_all'], label='Adam');
axs[0].legend();
axs[1].set_title('Rep Norm vs. Accuracy')
axs[1].scatter(mnist_sam_005[' st_acc_all'], mnist_sam_005[' rep_norm_all'], label='SAM');
axs[1].scatter(mnist_adam_005[' st_acc_all'], mnist_adam_005[' rep_norm_all'], label='Adam');
axs[1].legend();
axs[2].set_title('Rep Shift vs. Accuracy')
axs[2].scatter(mnist_sam_005[' st_acc_all'], mnist_sam_005[' st_rep_shift_all'], label='SAM');
axs[2].scatter(mnist_adam_005[' st_acc_all'], mnist_adam_005[' st_rep_shift_all'], label='Adam');
axs[2].legend();
print('Sharpness/Accuracy Correlation')
print('SAM', round(mnist_sam_005.corr()[' st_acc_all'].loc[' st_sharp_all'], 2))
print('Adam:', round(mnist_adam_005.corr()[' st_acc_all'].loc[' st_sharp_all'], 2))
print('Rep Norm/Accuracy Correlation')
print('SAM', round(mnist_sam_005.corr()[' st_acc_all'].loc[' rep_norm_all'], 2))
print('Adam:', round(mnist_adam_005.corr()[' st_acc_all'].loc[' rep_norm_all'], 2))
print('Rep Shift/Accuracy Correlation')
print('SAM', round(mnist_sam_005.corr()[' st_acc_all'].loc[' st_rep_shift_all'], 2))
print('Adam:', round(mnist_adam_005.corr()[' st_acc_all'].loc[' st_rep_shift_all'], 2), '\n')

print('Accuracy Comparison')
print('SAM:', round(np.mean(mnist_sam_005[' st_acc_all']), 2), round(np.std(mnist_sam_005[' st_acc_all']), 2), 'vs', 'Adam:',
      round(np.mean(mnist_adam_005[' st_acc_all']), 2), round(np.std(mnist_adam_005[' st_acc_all']), 2), '\n')

print('Sharpness Comparison')
print('SAM:', round(np.mean(mnist_sam_005[' st_sharp_all']), 3), 'vs', 'Adam:',
      round(np.mean(mnist_adam_005[' st_sharp_all']), 3), '\n')

print('Rep Shift Comparison')
print('SAM:', round(np.mean(mnist_sam_005[' st_rep_shift_all']), 2), 'vs', 'Adam:',
      round(np.mean(mnist_adam_005[' st_rep_shift_all']), 2), '\n')

print('Rep Norm Comparison')
print('SAM:', round(np.mean(mnist_sam_005[' rep_norm_all']), 2), 'vs', 'Adam:',
      round(np.mean(mnist_adam_005[' rep_norm_all']), 2))
# Out:
# Sharpness/Accuracy Correlation
# SAM -0.82
# Adam: 0.41
# Rep Norm/Accuracy Correlation
# SAM -0.6
# Adam: -0.13
# Rep Shift/Accuracy Correlation
# SAM -0.73
# Adam: -0.42
#
# Accuracy Comparison
# SAM: 62.73 0.86 vs Adam: 57.71 2.05
#
# Sharpness Comparison
# SAM: 0.25 vs Adam: 0.21
#
# Rep Shift Comparison
# SAM: 0.48 vs Adam: 0.48
#
# Rep Norm Comparison
# SAM: 32.58 vs Adam: 32.32

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(12,5))
axs[0].set_title('Sharpness vs. Accuracy')
axs[0].scatter(color_sam_005[' st_acc_all'], color_sam_005[' st_sharp_all'], label='SAM');
axs[0].scatter(color_adam_005[' st_acc_all'], color_adam_005[' st_sharp_all'], label='Adam');
axs[0].legend();
axs[1].set_title('Rep Norm vs. Accuracy')
axs[1].scatter(color_sam_005[' st_acc_all'], color_sam_005[' rep_norm_all'], label='SAM');
axs[1].scatter(color_adam_005[' st_acc_all'], color_adam_005[' rep_norm_all'], label='Adam');
axs[1].legend();
axs[2].set_title('Rep Shift vs. Accuracy')
axs[2].scatter(color_sam_005[' st_acc_all'], color_sam_005[' st_rep_shift_all'], label='SAM');
axs[2].scatter(color_adam_005[' st_acc_all'], color_adam_005[' st_rep_shift_all'], label='Adam');
axs[2].legend();
print('Sharpness/Accuracy Correlation')
print('SAM', round(color_sam_005.corr()[' st_acc_all'].loc[' st_sharp_all'], 2))
print('Adam:', round(color_adam_005.corr()[' st_acc_all'].loc[' st_sharp_all'], 2))
print('Rep Norm/Accuracy Correlation')
print('SAM', round(color_sam_005.corr()[' st_acc_all'].loc[' rep_norm_all'], 2))
print('Adam:', round(color_adam_005.corr()[' st_acc_all'].loc[' rep_norm_all'], 2))
print('Rep Shift/Accuracy Correlation')
print('SAM', round(color_sam_005.corr()[' st_acc_all'].loc[' st_rep_shift_all'], 2))
print('Adam:', round(color_adam_005.corr()[' st_acc_all'].loc[' st_rep_shift_all'], 2), '\n')

print('Accuracy Comparison')
print('SAM:', round(np.mean(color_sam_005[' st_acc_all']), 2), round(np.std(color_sam_005[' st_acc_all']), 2), 'vs', 'Adam:',
      round(np.mean(color_adam_005[' st_acc_all']), 2), round(np.std(color_adam_005[' st_acc_all']), 2), '\n')

print('Sharpness Comparison')
print('SAM:', round(np.mean(color_sam_005[' st_sharp_all']), 2), 'vs', 'Adam:',
      round(np.mean(color_adam_005[' st_sharp_all']), 2), '\n')

print('Rep Shift Comparison')
print('SAM:', round(np.mean(color_sam_005[' st_rep_shift_all']), 2), 'vs', 'Adam:',
      round(np.mean(color_adam_005[' st_rep_shift_all']), 2), '\n')

print('Rep Norm Comparison')
print('SAM:', round(np.mean(color_sam_005[' rep_norm_all']), 2), 'vs', 'Adam:',
      round(np.mean(color_adam_005[' rep_norm_all']), 2))
# Out:
# Sharpness/Accuracy Correlation
# SAM 0.54
# Adam: 0.42
# Rep Norm/Accuracy Correlation
# SAM -0.82
# Adam: -0.4
# Rep Shift/Accuracy Correlation
# SAM -0.98
# Adam: -0.94
#
# Accuracy Comparison
# SAM: 56.23 10.09 vs Adam: 34.07 16.09
#
# Sharpness Comparison
# SAM: 0.14 vs Adam: 0.63
#
# Rep Shift Comparison
# SAM: 0.22 vs Adam: 0.57
#
# Rep Norm Comparison
# SAM: 9.43 vs Adam: 20.28

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(12,5))
axs[0].set_title('Sharpness vs. Accuracy')
axs[0].scatter(portraits_sam_005[' st_acc_all'], portraits_sam_005[' st_sharp_all'], label='SAM');
axs[0].scatter(portraits_adam_005[' st_acc_all'], portraits_adam_005[' st_sharp_all'], label='Adam');
axs[0].legend();
axs[1].set_title('Rep Norm vs. Accuracy')
axs[1].scatter(portraits_sam_005[' st_acc_all'], portraits_sam_005[' rep_norm_all'], label='SAM');
axs[1].scatter(portraits_adam_005[' st_acc_all'], portraits_adam_005[' rep_norm_all'], label='Adam');
axs[1].legend();
axs[2].set_title('Rep Shift vs. Accuracy')
axs[2].scatter(portraits_sam_005[' st_acc_all'], portraits_sam_005[' st_rep_shift_all'], label='SAM');
axs[2].scatter(portraits_adam_005[' st_acc_all'], portraits_adam_005[' st_rep_shift_all'], label='Adam');
axs[2].legend();
print('Sharpness/Accuracy Correlation')
print('SAM', round(portraits_sam_005.corr()[' st_acc_all'].loc[' st_sharp_all'], 2))
print('Adam:', round(portraits_adam_005.corr()[' st_acc_all'].loc[' st_sharp_all'], 2))
print('Rep Norm/Accuracy Correlation')
print('SAM', round(portraits_sam_005.corr()[' st_acc_all'].loc[' rep_norm_all'], 2))
print('Adam:', round(portraits_adam_005.corr()[' st_acc_all'].loc[' rep_norm_all'], 2))
print('Rep Shift/Accuracy Correlation')
print('SAM', round(portraits_sam_005.corr()[' st_acc_all'].loc[' st_rep_shift_all'], 2))
print('Adam:', round(portraits_adam_005.corr()[' st_acc_all'].loc[' st_rep_shift_all'], 2), '\n')


print('Accuracy Comparison')
print('SAM:', round(np.mean(portraits_sam_005[' st_acc_all']), 2), round(np.std(portraits_sam_005[' st_acc_all']), 2), 'vs', 'Adam:',
      round(np.mean(portraits_adam_005[' st_acc_all']), 2), round(np.std(portraits_adam_005[' st_acc_all']), 2), '\n')

print('Sharpness Comparison')
print('SAM:', round(np.mean(portraits_sam_005[' st_sharp_all']), 2), 'vs', 'Adam:',
      round(np.mean(portraits_adam_005[' st_sharp_all']), 2), '\n')

print('Rep Shift Comparison')
print('SAM:', round(np.mean(portraits_sam_005[' st_rep_shift_all']), 2), 'vs', 'Adam:',
      round(np.mean(portraits_adam_005[' st_rep_shift_all']), 2), '\n')

print('Rep Norm Comparison')
print('SAM:', round(np.mean(portraits_sam_005[' rep_norm_all']), 2), 'vs', 'Adam:',
      round(np.mean(portraits_adam_005[' rep_norm_all']), 2))
# Out:
# Sharpness/Accuracy Correlation
# SAM -0.29
# Adam: 0.98
# Rep Norm/Accuracy Correlation
# SAM 0.28
# Adam: -0.65
# Rep Shift/Accuracy Correlation
# SAM -0.64
# Adam: -0.28
#
# Accuracy Comparison
# SAM: 73.25 1.94 vs Adam: 75.88 1.43
#
# Sharpness Comparison
# SAM: 0.06 vs Adam: 0.15
#
# Rep Shift Comparison
# SAM: 0.12 vs Adam: 0.18
#
# Rep Norm Comparison
# SAM: 1.49 vs Adam: 2.9

# %% [markdown]
# ## Main Rho Ablation Plot

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as mtick

sns.set(font_scale=1.1)
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300
# plt.rcParams['text.usetex'] = True
# plt.rcParams['text.latex.preamble'] = r'\usepackage{dsfont}'

from IPython.display import set_matplotlib_formats
set_matplotlib_formats('png', 'pdf')

import warnings
warnings.filterwarnings('ignore')
colors = ['lightsteelblue', 'cornflowerblue', 'blue', 'midnightblue', 'green', 'red']
label_size = 23
legend_size = 18
x_log_scale = False

# %%
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(12,8), constrained_layout=True)
# Covertype
covtype_adam_005 = pd.read_csv('logs/covtype_adam_0.05_100ep.txt')
covtype_sam_001 = pd.read_csv('logs/covtype_sam_0.01_100ep.txt')
covtype_sam_002 = pd.read_csv('logs/covtype_sam_0.02_100ep.txt')
covtype_sam_005 = pd.read_csv('logs/covtype_sam_0.05_100ep.txt')
covtype_sam_010 = pd.read_csv('logs/covtype_sam_0.1_100ep.txt')
covtype_sam_020 = pd.read_csv('logs/covtype_sam_0.2_100ep.txt')

means = np.array([covtype_sam_001[' st_acc_all'].mean(), covtype_sam_002[' st_acc_all'].mean(), covtype_sam_005[' st_acc_all'].mean(), covtype_sam_010[' st_acc_all'].mean(), covtype_sam_020[' st_acc_all'].mean()])
means = 100-means
std_devs = np.array([covtype_sam_001[' st_acc_all'].std(), covtype_sam_002[' st_acc_all'].std(), covtype_sam_005[' st_acc_all'].std(), covtype_sam_010[' st_acc_all'].std(), covtype_sam_020[' st_acc_all'].std()])
rhos = [0.01, 0.02, 0.05, 0.1, 0.2]

axs[1][1].set_title('Cover Type', fontsize=12)
axs[1][1].plot(rhos, means, color=colors[1], label='SAM');
axs[1][1].fill_between(rhos, means-std_devs, means+std_devs, alpha=0.2, color=colors[1]);
axs[1][1].plot(rhos, 100-np.repeat(covtype_adam_005[' st_acc_all'].mean(), 5), linestyle='--', color='red', label='Adam')
axs[1][1].set_ylabel('Target Domain Error');
axs[1][1].set_xlabel('Rho')
axs[1][1].set_xticks(rhos);
axs[1][1].set_xscale('log')
axs[1][1].legend();

# Portraits
portraits_adam_005 = pd.read_csv('logs/portraits_adam_0.05_100ep.txt')
portraits_sam_001 = pd.read_csv('logs/portraits_sam_0.01_100ep.txt')
portraits_sam_002 = pd.read_csv('logs/portraits_sam_0.02_100ep.txt')
portraits_sam_005 = pd.read_csv('logs/portraits_sam_0.05_100ep.txt')
portraits_sam_010 = pd.read_csv('logs/portraits_sam_0.1_100ep.txt')
portraits_sam_020 = pd.read_csv('logs/portraits_sam_0.2_100ep.txt')

means = np.array([portraits_sam_001[' st_acc_all'].mean(), portraits_sam_002[' st_acc_all'].mean(), portraits_sam_005[' st_acc_all'].mean(), portraits_sam_010[' st_acc_all'].mean(), portraits_sam_020[' st_acc_all'].mean()])
means = 100-means
std_devs = np.array([portraits_sam_001[' st_acc_all'].std(), portraits_sam_002[' st_acc_all'].std(), portraits_sam_005[' st_acc_all'].std(), portraits_sam_010[' st_acc_all'].std(), portraits_sam_020[' st_acc_all'].std()])

axs[1][0].set_title('Portraits', fontsize=12)
axs[1][0].plot(rhos, means, color=colors[1], label='SAM');
axs[1][0].fill_between(rhos, means-std_devs, means+std_devs, alpha=0.2, color=colors[1]);
axs[1][0].plot(rhos, 100-np.repeat(portraits_adam_005[' st_acc_all'].mean(), 5), linestyle='--', color='red', label='Adam')
axs[1][0].set_ylabel('Target Domain Error');
axs[1][0].set_xlabel('Rho')
axs[1][0].set_xticks(rhos);
axs[1][0].set_xscale('log')
axs[1][0].legend();

# Color MNIST
color_adam_005 = pd.read_csv('logs/color_adam_0.05_100ep.txt')
color_sam_001 = pd.read_csv('logs/color_sam_0.01_100ep.txt')
color_sam_002 = pd.read_csv('logs/color_sam_0.02_100ep.txt')
color_sam_005 = pd.read_csv('logs/color_sam_0.05_100ep.txt')
color_sam_010 = pd.read_csv('logs/color_sam_0.1_100ep.txt')
color_sam_020 = pd.read_csv('logs/color_sam_0.2_100ep.txt')

means = np.array([color_sam_001[' st_acc_all'].mean(), color_sam_002[' st_acc_all'].mean(), color_sam_005[' st_acc_all'].mean(), color_sam_010[' st_acc_all'].mean(), color_sam_020[' st_acc_all'].mean()])
means = 100-means
std_devs = np.array([color_sam_001[' st_acc_all'].std(), color_sam_002[' st_acc_all'].std(), color_sam_005[' st_acc_all'].std(), color_sam_010[' st_acc_all'].std(), color_sam_020[' st_acc_all'].std()])

axs[0][0].set_title('Color Shifted MNIST', fontsize=12)
axs[0][0].plot(rhos, means, color=colors[1], label='SAM');
axs[0][0].fill_between(rhos, means-std_devs, means+std_devs, alpha=0.2, color=colors[1]);
axs[0][0].plot(rhos, 100-np.repeat(color_adam_005[' st_acc_all'].mean(), 5), linestyle='--', color='red', label='Adam')
axs[0][0].set_ylabel('Target Domain Error');
axs[0][0].set_xticks(rhos);
axs[0][0].set_xscale('log')
axs[0][0].legend();

# Rotated MNIST
# rotate_adam_005 = pd.read_csv('logs/mnist_adam_0.05_100ep.txt')
# rotate_sam_001 = pd.read_csv('logs/mnist_sam_0.01_100ep.txt')
# rotate_sam_002 = pd.read_csv('logs/mnist_sam_0.02_100ep.txt')
# rotate_sam_005 = pd.read_csv('logs/mnist_sam_0.05_100ep.txt')
# rotate_sam_010 = pd.read_csv('logs/mnist_sam_0.1_100ep.txt')
# rotate_sam_020 = pd.read_csv('logs/mnist_sam_0.2_100ep.txt')

# means = np.array([rotate_sam_001[' st_acc_all'].mean(), rotate_sam_002[' st_acc_all'].mean(), rotate_sam_005[' st_acc_all'].mean(), rotate_sam_010[' st_acc_all'].mean(), rotate_sam_020[' st_acc_all'].mean()])
# std_devs = np.array([rotate_sam_001[' st_acc_all'].std(), rotate_sam_002[' st_acc_all'].std(), rotate_sam_005[' st_acc_all'].std(), rotate_sam_010[' st_acc_all'].std(), rotate_sam_020[' st_acc_all'].std()])

axs[0][1].set_title('Rotated MNIST (45 degrees)', fontsize=12)
axs[0][1].plot(rhos, means, color=colors[1], label='SAM');
axs[0][1].fill_between(rhos, means-std_devs, means+std_devs, alpha=0.2, color=colors[1]);
axs[0][1].plot(rhos, 100-np.repeat(color_adam_005[' st_acc_all'].mean(), 5), linestyle='--', color='red', label='Adam') #TODO: change to rotate_adam_005
axs[0][1].set_ylabel('Target Domain Error');
axs[0][1].set_xticks(rhos);
axs[0][1].set_xscale('log')
axs[0][1].legend();
