# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
mnist_adam_005 = pd.read_csv('logs/mnist_adam_0.05.txt')
mnist_sam_005 = pd.read_csv('logs/mnist_sam_0.05.txt')

# %%
mnist_adam_005.mean(axis=0), mnist_adam_005.std(axis=0)
# Out:
# /tmp/ipykernel_3468025/4051588050.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mnist_adam_005.mean(axis=0), mnist_adam_005.std(axis=0)
# (direct_acc           44.337
#   st_acc              45.442
#   direct_acc_all      44.337
#   st_acc_all          54.405
#   generated_acc        0.000
#   st_rep_shift         0.000
#   st_rep_shift_all     0.540
#   st_sharp             0.175
#   st_sharp_all         0.161
#   rep_norm             8.144
#   rep_norm_all         9.877
#  dtype: float64,
#  direct_acc           1.936308
#   st_acc              2.138134
#   direct_acc_all      1.936308
#   st_acc_all          2.927203
#   generated_acc       0.000000
#   st_rep_shift        0.000000
#   st_rep_shift_all    0.038297
#   st_sharp            0.058547
#   st_sharp_all        0.041486
#   rep_norm            0.168536
#   rep_norm_all        0.241019
#  dtype: float64)

# %%
mnist_sam_005.mean(axis=0), mnist_sam_005.std(axis=0)
# Out:
# /tmp/ipykernel_3468025/2763551878.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mnist_sam_005.mean(axis=0), mnist_sam_005.std(axis=0)
# (direct_acc           43.714
#   st_acc              44.885
#   direct_acc_all      43.714
#   st_acc_all          54.177
#   generated_acc        0.000
#   st_rep_shift         0.000
#   st_rep_shift_all     0.519
#   st_sharp             0.228
#   st_sharp_all         0.158
#   rep_norm             8.068
#   rep_norm_all         9.777
#  dtype: float64,
#  direct_acc           1.613045
#   st_acc              1.823582
#   direct_acc_all      1.613045
#   st_acc_all          2.872061
#   generated_acc       0.000000
#   st_rep_shift        0.000000
#   st_rep_shift_all    0.024698
#   st_sharp            0.067297
#   st_sharp_all        0.053292
#   rep_norm            0.263810
#   rep_norm_all        0.238003
#  dtype: float64)

# %%
color_adam_005 = pd.read_csv('logs/color_adam_0.05.txt')
color_sam_005 = pd.read_csv('logs/color_sam_0.05.txt')

# %%
color_sam_005.corr()
# Out:
#                    direct_acc    st_acc   direct_acc_all   st_acc_all  \
# direct_acc           1.000000  0.914769         1.000000     0.944268
#  st_acc              0.914769  1.000000         0.914769     0.808201
#  direct_acc_all      1.000000  0.914769         1.000000     0.944268
#  st_acc_all          0.944268  0.808201         0.944268     1.000000
#  generated_acc            NaN       NaN              NaN          NaN
#  st_rep_shift             NaN       NaN              NaN          NaN
#  st_rep_shift_all   -0.972145 -0.874715        -0.972145    -0.980221
#  st_sharp           -0.619136 -0.738648        -0.619136    -0.546303
#  st_sharp_all       -0.348734 -0.280719        -0.348734    -0.429006
#  rep_norm            0.016739  0.039765         0.016739    -0.003792
#  rep_norm_all       -0.018967  0.003103        -0.018967    -0.011759
#
#                     generated_acc   st_rep_shift   st_rep_shift_all  \
# direct_acc                    NaN            NaN          -0.972145
#  st_acc                       NaN            NaN          -0.874715
#  direct_acc_all               NaN            NaN          -0.972145
#  st_acc_all                   NaN            NaN          -0.980221
#  generated_acc                NaN            NaN                NaN
#  st_rep_shift                 NaN            NaN                NaN
#  st_rep_shift_all             NaN            NaN           1.000000
#  st_sharp                     NaN            NaN           0.618689
#  st_sharp_all                 NaN            NaN           0.396649
#  rep_norm                     NaN            NaN           0.032006
#  rep_norm_all                 NaN            NaN           0.055010
#
#                     st_sharp   st_sharp_all   rep_norm   rep_norm_all
# direct_acc         -0.619136      -0.348734   0.016739      -0.018967
#  st_acc            -0.738648      -0.280719   0.039765       0.003103
#  direct_acc_all    -0.619136      -0.348734   0.016739      -0.018967
#  st_acc_all        -0.546303      -0.429006  -0.003792      -0.011759
#  generated_acc           NaN            NaN        NaN            NaN
#  st_rep_shift            NaN            NaN        NaN            NaN
#  st_rep_shift_all   0.618689       0.396649   0.032006       0.055010
#  st_sharp           1.000000       0.257879   0.262762       0.290668
#  st_sharp_all       0.257879       1.000000  -0.039485       0.031329
#  rep_norm           0.262762      -0.039485   1.000000       0.990477
#  rep_norm_all       0.290668       0.031329   0.990477       1.000000

# %%
color_adam_005.corr()
# Out:
#                    direct_acc    st_acc   direct_acc_all   st_acc_all  \
# direct_acc           1.000000  0.923220         1.000000     0.876138
#  st_acc              0.923220  1.000000         0.923220     0.854338
#  direct_acc_all      1.000000  0.923220         1.000000     0.876138
#  st_acc_all          0.876138  0.854338         0.876138     1.000000
#  generated_acc            NaN       NaN              NaN          NaN
#  st_rep_shift             NaN       NaN              NaN          NaN
#  st_rep_shift_all   -0.731768 -0.783358        -0.731768    -0.789502
#  st_sharp            0.147115  0.046505         0.147115     0.104300
#  st_sharp_all       -0.398890 -0.255434        -0.398890    -0.397824
#  rep_norm            0.587556  0.647349         0.587556     0.396429
#  rep_norm_all        0.845693  0.861339         0.845693     0.800839
#
#                     generated_acc   st_rep_shift   st_rep_shift_all  \
# direct_acc                    NaN            NaN          -0.731768
#  st_acc                       NaN            NaN          -0.783358
#  direct_acc_all               NaN            NaN          -0.731768
#  st_acc_all                   NaN            NaN          -0.789502
#  generated_acc                NaN            NaN                NaN
#  st_rep_shift                 NaN            NaN                NaN
#  st_rep_shift_all             NaN            NaN           1.000000
#  st_sharp                     NaN            NaN           0.004101
#  st_sharp_all                 NaN            NaN           0.420633
#  rep_norm                     NaN            NaN          -0.340657
#  rep_norm_all                 NaN            NaN          -0.557859
#
#                     st_sharp   st_sharp_all   rep_norm   rep_norm_all
# direct_acc          0.147115      -0.398890   0.587556       0.845693
#  st_acc             0.046505      -0.255434   0.647349       0.861339
#  direct_acc_all     0.147115      -0.398890   0.587556       0.845693
#  st_acc_all         0.104300      -0.397824   0.396429       0.800839
#  generated_acc           NaN            NaN        NaN            NaN
#  st_rep_shift            NaN            NaN        NaN            NaN
#  st_rep_shift_all   0.004101       0.420633  -0.340657      -0.557859
#  st_sharp           1.000000       0.479756   0.067584       0.166278
#  st_sharp_all       0.479756       1.000000   0.060430      -0.106076
#  rep_norm           0.067584       0.060430   1.000000       0.836598
#  rep_norm_all       0.166278      -0.106076   0.836598       1.000000

# %%
color_adam_005.mean(axis=0), color_adam_005.std(axis=0)
# Out:
# /tmp/ipykernel_3468025/4246944216.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   color_adam_005.mean(axis=0), color_adam_005.std(axis=0)
# (direct_acc           25.320
#   st_acc              28.210
#   direct_acc_all      25.320
#   st_acc_all          36.660
#   generated_acc        0.000
#   st_rep_shift         0.000
#   st_rep_shift_all     0.350
#   st_sharp             0.518
#   st_sharp_all         0.551
#   rep_norm             8.782
#   rep_norm_all         9.291
#  dtype: float64,
#  direct_acc            9.347882
#   st_acc               8.780749
#   direct_acc_all       9.347882
#   st_acc_all          15.167048
#   generated_acc        0.000000
#   st_rep_shift         0.000000
#   st_rep_shift_all     0.058500
#   st_sharp             0.370519
#   st_sharp_all         0.230287
#   rep_norm             0.331186
#   rep_norm_all         0.554966
#  dtype: float64)

# %%
color_sam_005.mean(axis=0), color_sam_005.std(axis=0)
# Out:
# /tmp/ipykernel_3468025/3335764934.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   color_sam_005.mean(axis=0), color_sam_005.std(axis=0)
# (direct_acc           35.050
#   st_acc              45.530
#   direct_acc_all      35.050
#   st_acc_all          44.900
#   generated_acc        0.000
#   st_rep_shift         0.000
#   st_rep_shift_all     0.163
#   st_sharp             0.260
#   st_sharp_all         0.148
#   rep_norm             5.027
#   rep_norm_all         5.196
#  dtype: float64,
#  direct_acc            8.732697
#   st_acc              13.399569
#   direct_acc_all       8.732697
#   st_acc_all          12.939496
#   generated_acc        0.000000
#   st_rep_shift         0.000000
#   st_rep_shift_all     0.031287
#   st_sharp             0.218123
#   st_sharp_all         0.063210
#   rep_norm             0.220809
#   rep_norm_all         0.214331
#  dtype: float64)

# %%
portraits_adam_005 = pd.read_csv('logs/portraits_adam_0.05.txt')
portraits_sam_005 = pd.read_csv('logs/portraits_sam_0.05.txt')

# %%
portraits_adam_005.corr()
# Out:
#                    direct_acc    st_acc   direct_acc_all   st_acc_all  \
# direct_acc           1.000000  0.982247         1.000000     0.632771
#  st_acc              0.982247  1.000000         0.982247     0.672167
#  direct_acc_all      1.000000  0.982247         1.000000     0.632771
#  st_acc_all          0.632771  0.672167         0.632771     1.000000
#  generated_acc            NaN       NaN              NaN          NaN
#  st_rep_shift             NaN       NaN              NaN          NaN
#  st_rep_shift_all   -0.029902 -0.036558        -0.029902    -0.427284
#  st_sharp            0.546755  0.569838         0.546755     0.586433
#  st_sharp_all       -0.045487 -0.039439        -0.045487     0.206535
#  rep_norm            0.050842 -0.060495         0.050842    -0.497021
#  rep_norm_all       -0.354724 -0.443089        -0.354724    -0.775153
#
#                     generated_acc   st_rep_shift   st_rep_shift_all  \
# direct_acc                    NaN            NaN      -2.990174e-02
#  st_acc                       NaN            NaN      -3.655783e-02
#  direct_acc_all               NaN            NaN      -2.990174e-02
#  st_acc_all                   NaN            NaN      -4.272845e-01
#  generated_acc                NaN            NaN                NaN
#  st_rep_shift                 NaN            NaN                NaN
#  st_rep_shift_all             NaN            NaN       1.000000e+00
#  st_sharp                     NaN            NaN      -4.800242e-01
#  st_sharp_all                 NaN            NaN      -7.757716e-01
#  rep_norm                     NaN            NaN      -1.670764e-01
#  rep_norm_all                 NaN            NaN      -1.223457e-07
#
#                     st_sharp   st_sharp_all   rep_norm   rep_norm_all
# direct_acc          0.546755      -0.045487   0.050842  -3.547240e-01
#  st_acc             0.569838      -0.039439  -0.060495  -4.430890e-01
#  direct_acc_all     0.546755      -0.045487   0.050842  -3.547240e-01
#  st_acc_all         0.586433       0.206535  -0.497021  -7.751532e-01
#  generated_acc           NaN            NaN        NaN            NaN
#  st_rep_shift            NaN            NaN        NaN            NaN
#  st_rep_shift_all  -0.480024      -0.775772  -0.167076  -1.223457e-07
#  st_sharp           1.000000       0.053581   0.057728  -2.645480e-01
#  st_sharp_all       0.053581       1.000000   0.135798   4.976612e-03
#  rep_norm           0.057728       0.135798   1.000000   8.875574e-01
#  rep_norm_all      -0.264548       0.004977   0.887557   1.000000e+00

# %%
portraits_sam_005.corr()
# Out:
#                    direct_acc    st_acc   direct_acc_all   st_acc_all  \
# direct_acc           1.000000  0.797312         1.000000     0.561565
#  st_acc              0.797312  1.000000         0.797312     0.362589
#  direct_acc_all      1.000000  0.797312         1.000000     0.561565
#  st_acc_all          0.561565  0.362589         0.561565     1.000000
#  generated_acc            NaN       NaN              NaN          NaN
#  st_rep_shift             NaN       NaN              NaN          NaN
#  st_rep_shift_all   -0.401288 -0.263163        -0.401288    -0.916187
#  st_sharp           -0.240620 -0.446742        -0.240620     0.335744
#  st_sharp_all        0.311259 -0.086102         0.311259     0.282492
#  rep_norm            0.028337 -0.142052         0.028337     0.140385
#  rep_norm_all       -0.106322 -0.233765        -0.106322     0.062907
#
#                     generated_acc   st_rep_shift   st_rep_shift_all  \
# direct_acc                    NaN            NaN          -0.401288
#  st_acc                       NaN            NaN          -0.263163
#  direct_acc_all               NaN            NaN          -0.401288
#  st_acc_all                   NaN            NaN          -0.916187
#  generated_acc                NaN            NaN                NaN
#  st_rep_shift                 NaN            NaN                NaN
#  st_rep_shift_all             NaN            NaN           1.000000
#  st_sharp                     NaN            NaN          -0.450679
#  st_sharp_all                 NaN            NaN          -0.316980
#  rep_norm                     NaN            NaN          -0.216820
#  rep_norm_all                 NaN            NaN          -0.144108
#
#                     st_sharp   st_sharp_all   rep_norm   rep_norm_all
# direct_acc         -0.240620       0.311259   0.028337      -0.106322
#  st_acc            -0.446742      -0.086102  -0.142052      -0.233765
#  direct_acc_all    -0.240620       0.311259   0.028337      -0.106322
#  st_acc_all         0.335744       0.282492   0.140385       0.062907
#  generated_acc           NaN            NaN        NaN            NaN
#  st_rep_shift            NaN            NaN        NaN            NaN
#  st_rep_shift_all  -0.450679      -0.316980  -0.216820      -0.144108
#  st_sharp           1.000000       0.435332   0.482089       0.529563
#  st_sharp_all       0.435332       1.000000   0.077466       0.026914
#  rep_norm           0.482089       0.077466   1.000000       0.987138
#  rep_norm_all       0.529563       0.026914   0.987138       1.000000

# %%
portraits_adam_005.mean(axis=0), portraits_adam_005.std(axis=0)
# Out:
# /tmp/ipykernel_3468025/1947504754.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   portraits_adam_005.mean(axis=0), portraits_adam_005.std(axis=0)
# (direct_acc           75.072222
#   st_acc              75.888889
#   direct_acc_all      75.072222
#   st_acc_all          77.027778
#   generated_acc        0.000000
#   st_rep_shift         0.000000
#   st_rep_shift_all     0.162222
#   st_sharp             0.156667
#   st_sharp_all         0.071111
#   rep_norm             1.536667
#   rep_norm_all         1.560000
#  dtype: float64,
#  direct_acc           2.179035
#   st_acc              2.047983
#   direct_acc_all      2.179035
#   st_acc_all          1.765487
#   generated_acc       0.000000
#   st_rep_shift        0.000000
#   st_rep_shift_all    0.017159
#   st_sharp            0.112805
#   st_sharp_all        0.077208
#   rep_norm            0.101735
#   rep_norm_all        0.097596
#  dtype: float64)

# %%
portraits_sam_005.mean(axis=0), portraits_sam_005.std(axis=0)
# Out:
# /tmp/ipykernel_3468025/1141642322.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   portraits_sam_005.mean(axis=0), portraits_sam_005.std(axis=0)
# (direct_acc           69.125
#   st_acc              73.275
#   direct_acc_all      69.125
#   st_acc_all          74.780
#   generated_acc        0.000
#   st_rep_shift         0.000
#   st_rep_shift_all     0.076
#   st_sharp             0.079
#   st_sharp_all         0.114
#   rep_norm             0.880
#   rep_norm_all         0.892
#  dtype: float64,
#  direct_acc           4.574097
#   st_acc              2.830611
#   direct_acc_all      4.574097
#   st_acc_all          4.800185
#   generated_acc       0.000000
#   st_rep_shift        0.000000
#   st_rep_shift_all    0.013499
#   st_sharp            0.061001
#   st_sharp_all        0.050376
#   rep_norm            0.079722
#   rep_norm_all        0.075395
#  dtype: float64)

# %%
covtype_adam_005 = pd.read_csv('logs/covtype_adam_0.05.txt')
covtype_sam_005 = pd.read_csv('logs/covtype_sam_0.05.txt')
covtype_sam_01 = pd.read_csv('logs/covtype_sam_0.1.txt')

# %%
covtype_adam_005.mean(axis=0), covtype_adam_005.std(axis=0)
# Out:
# /tmp/ipykernel_3468025/631035434.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   covtype_adam_005.mean(axis=0), covtype_adam_005.std(axis=0)
# (direct_acc            65.390
#   st_acc               65.317
#   direct_acc_all       65.390
#   st_acc_all           69.505
#   generated_acc         0.000
#   st_rep_shift          0.000
#   st_rep_shift_all      1.276
#   st_sharp              0.076
#   st_sharp_all          0.066
#   rep_norm            270.952
#   rep_norm_all        256.330
#  dtype: float64,
#  direct_acc            5.264310
#   st_acc               5.325202
#   direct_acc_all       5.264310
#   st_acc_all           4.301620
#   generated_acc        0.000000
#   st_rep_shift         0.000000
#   st_rep_shift_all     0.260436
#   st_sharp             0.042216
#   st_sharp_all         0.042740
#   rep_norm            11.184046
#   rep_norm_all         6.315756
#  dtype: float64)

# %%
covtype_sam_005.mean(axis=0), covtype_sam_005.std(axis=0)
# Out:
# /tmp/ipykernel_3468025/4101694542.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   covtype_sam_005.mean(axis=0), covtype_sam_005.std(axis=0)
# (direct_acc            60.261
#   st_acc               60.112
#   direct_acc_all       60.261
#   st_acc_all           60.399
#   generated_acc         0.000
#   st_rep_shift          0.000
#   st_rep_shift_all      0.042
#   st_sharp              0.033
#   st_sharp_all          0.028
#   rep_norm            258.704
#   rep_norm_all        256.733
#  dtype: float64,
#  direct_acc           3.847725
#   st_acc              4.517122
#   direct_acc_all      3.847725
#   st_acc_all          3.399760
#   generated_acc       0.000000
#   st_rep_shift        0.000000
#   st_rep_shift_all    0.028983
#   st_sharp            0.023594
#   st_sharp_all        0.045166
#   rep_norm            1.691615
#   rep_norm_all        0.532354
#  dtype: float64)

# %%
covtype_sam_01.mean(axis=0), covtype_sam_01.std(axis=0)
# Out:
# /tmp/ipykernel_3468025/2192646419.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   covtype_sam_01.mean(axis=0), covtype_sam_01.std(axis=0)
# (direct_acc            59.966
#   st_acc               58.962
#   direct_acc_all       59.966
#   st_acc_all           60.451
#   generated_acc         0.000
#   st_rep_shift          0.000
#   st_rep_shift_all      0.082
#   st_sharp              0.060
#   st_sharp_all          0.044
#   rep_norm            259.085
#   rep_norm_all        257.350
#  dtype: float64,
#  direct_acc           2.393826
#   st_acc              2.680837
#   direct_acc_all      2.393826
#   st_acc_all          3.996286
#   generated_acc       0.000000
#   st_rep_shift        0.000000
#   st_rep_shift_all    0.045656
#   st_sharp            0.031972
#   st_sharp_all        0.068020
#   rep_norm            2.061818
#   rep_norm_all        0.758624
#  dtype: float64)

# %%
covtype_sam_005[' st_acc_all']=100-covtype_sam_005[' st_acc_all']
covtype_adam_005[' st_acc_all']=100-covtype_adam_005[' st_acc_all']

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(12,5))
axs[0].set_title('Sharpness vs. Error')
axs[0].scatter(covtype_sam_005[' st_acc_all'], covtype_sam_005[' st_sharp_all'], label='SAM');
axs[0].scatter(covtype_adam_005[' st_acc_all'], covtype_adam_005[' st_sharp_all'], label='Adam');
axs[0].legend();
axs[1].set_title('Rep Norm vs. Error')
axs[1].scatter(covtype_sam_005[' st_acc_all'], covtype_sam_005[' rep_norm_all'], label='SAM');
axs[1].scatter(covtype_adam_005[' st_acc_all'], covtype_adam_005[' rep_norm_all'], label='Adam');
axs[1].legend();
axs[2].set_title('Rep Shift vs. Error')
axs[2].scatter(covtype_sam_005[' st_acc_all'], covtype_sam_005[' st_rep_shift_all'], label='SAM');
axs[2].scatter(covtype_adam_005[' st_acc_all'], covtype_adam_005[' st_rep_shift_all'], label='Adam');
axs[2].legend();
print('Sharpness/Error Correlation')
print('SAM', round(covtype_sam_005.corr()[' st_acc_all'].loc[' st_sharp_all'], 2))
print('Adam:', round(covtype_adam_005.corr()[' st_acc_all'].loc[' st_sharp_all'], 2))
print('Rep Norm/Error Correlation')
print('SAM', round(covtype_sam_005.corr()[' st_acc_all'].loc[' rep_norm_all'], 2))
print('Adam:', round(covtype_adam_005.corr()[' st_acc_all'].loc[' rep_norm_all'], 2))
print('Rep Shift/Error Correlation')
print('SAM', round(covtype_sam_005.corr()[' st_acc_all'].loc[' st_rep_shift_all'], 2))
print('Adam:', round(covtype_adam_005.corr()[' st_acc_all'].loc[' st_rep_shift_all'], 2), '\n')

print('Error Comparison')
print('SAM:', round(np.mean(covtype_sam_005[' st_acc_all']), 2), 'vs', 'Adam:',
      round(np.mean(covtype_adam_005[' st_acc_all']), 2), '\n')

print('Sharpness Comparison')
print('SAM:', round(np.mean(covtype_sam_005[' st_sharp_all']), 2), 'vs', 'Adam:',
      round(np.mean(covtype_adam_005[' st_sharp_all']), 2), '\n')

print('Rep Shift Comparison')
print('SAM:', round(np.mean(covtype_sam_005[' st_rep_shift_all']), 2), 'vs', 'Adam:',
      round(np.mean(covtype_adam_005[' st_rep_shift_all']), 2), '\n')

print('Rep Norm Comparison')
print('SAM:', round(np.mean(covtype_sam_005[' rep_norm_all']), 2), 'vs', 'Adam:',
      round(np.mean(covtype_adam_005[' rep_norm_all']), 2))
# Out:
# Sharpness/Error Correlation
# SAM 0.26
# Adam: -0.1
# Rep Norm/Error Correlation
# SAM 0.03
# Adam: 0.89
# Rep Shift/Error Correlation
# SAM 0.1
# Adam: 0.73
#
# Error Comparison
# SAM: 39.6 vs Adam: 30.5
#
# Sharpness Comparison
# SAM: 0.03 vs Adam: 0.07
#
# Rep Shift Comparison
# SAM: 0.04 vs Adam: 1.28
#
# Rep Norm Comparison
# SAM: 256.73 vs Adam: 256.33

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(12,5))
axs[0].set_title('Sharpness vs. Accuracy')
axs[0].scatter(mnist_sam_005[' st_acc_all'], mnist_sam_005[' st_sharp_all'], label='SAM');
axs[0].scatter(mnist_adam_005[' st_acc_all'], mnist_adam_005[' st_sharp_all'], label='Adam');
axs[0].legend();
axs[1].set_title('Rep Norm vs. Accuracy')
axs[1].scatter(mnist_sam_005[' st_acc_all'], mnist_sam_005[' rep_norm_all'], label='SAM');
axs[1].scatter(mnist_adam_005[' st_acc_all'], mnist_adam_005[' rep_norm_all'], label='Adam');
axs[1].legend();
axs[2].set_title('Rep Shift vs. Accuracy')
axs[2].scatter(mnist_sam_005[' st_acc_all'], mnist_sam_005[' st_rep_shift_all'], label='SAM');
axs[2].scatter(mnist_adam_005[' st_acc_all'], mnist_adam_005[' st_rep_shift_all'], label='Adam');
axs[2].legend();
print('Sharpness/Accuracy Correlation')
print('SAM', round(mnist_sam_005.corr()[' st_acc_all'].loc[' st_sharp_all'], 2))
print('Adam:', round(mnist_adam_005.corr()[' st_acc_all'].loc[' st_sharp_all'], 2))
print('Rep Norm/Accuracy Correlation')
print('SAM', round(mnist_sam_005.corr()[' st_acc_all'].loc[' rep_norm_all'], 2))
print('Adam:', round(mnist_adam_005.corr()[' st_acc_all'].loc[' rep_norm_all'], 2))
print('Rep Shift/Accuracy Correlation')
print('SAM', round(mnist_sam_005.corr()[' st_acc_all'].loc[' st_rep_shift_all'], 2))
print('Adam:', round(mnist_adam_005.corr()[' st_acc_all'].loc[' st_rep_shift_all'], 2), '\n')

print('Accuracy Comparison')
print('SAM:', round(np.mean(mnist_sam_005[' st_acc_all']), 2), 'vs', 'Adam:',
      round(np.mean(mnist_adam_005[' st_acc_all']), 2), '\n')

print('Sharpness Comparison')
print('SAM:', round(np.mean(mnist_sam_005[' st_sharp_all']), 3), 'vs', 'Adam:',
      round(np.mean(mnist_adam_005[' st_sharp_all']), 3), '\n')

print('Rep Shift Comparison')
print('SAM:', round(np.mean(mnist_sam_005[' st_rep_shift_all']), 2), 'vs', 'Adam:',
      round(np.mean(mnist_adam_005[' st_rep_shift_all']), 2), '\n')

print('Rep Norm Comparison')
print('SAM:', round(np.mean(mnist_sam_005[' rep_norm_all']), 2), 'vs', 'Adam:',
      round(np.mean(mnist_adam_005[' rep_norm_all']), 2))
# Out:
# Sharpness/Accuracy Correlation
# SAM -0.33
# Adam: 0.19
# Rep Norm/Accuracy Correlation
# SAM 0.52
# Adam: -0.59
# Rep Shift/Accuracy Correlation
# SAM -0.3
# Adam: -0.18
#
# Accuracy Comparison
# SAM: 54.18 vs Adam: 54.4
#
# Sharpness Comparison
# SAM: 0.158 vs Adam: 0.161
#
# Rep Shift Comparison
# SAM: 0.52 vs Adam: 0.54
#
# Rep Norm Comparison
# SAM: 9.78 vs Adam: 9.88

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(12,5))
axs[0].set_title('Sharpness vs. Accuracy')
axs[0].scatter(color_sam_005[' st_acc_all'], color_sam_005[' st_sharp_all'], label='SAM');
axs[0].scatter(color_adam_005[' st_acc_all'], color_adam_005[' st_sharp_all'], label='Adam');
axs[0].legend();
axs[1].set_title('Rep Norm vs. Accuracy')
axs[1].scatter(color_sam_005[' st_acc_all'], color_sam_005[' rep_norm_all'], label='SAM');
axs[1].scatter(color_adam_005[' st_acc_all'], color_adam_005[' rep_norm_all'], label='Adam');
axs[1].legend();
axs[2].set_title('Rep Shift vs. Accuracy')
axs[2].scatter(color_sam_005[' st_acc_all'], color_sam_005[' st_rep_shift_all'], label='SAM');
axs[2].scatter(color_adam_005[' st_acc_all'], color_adam_005[' st_rep_shift_all'], label='Adam');
axs[2].legend();
print('Sharpness/Accuracy Correlation')
print('SAM', round(color_sam_005.corr()[' st_acc_all'].loc[' st_sharp_all'], 2))
print('Adam:', round(color_adam_005.corr()[' st_acc_all'].loc[' st_sharp_all'], 2))
print('Rep Norm/Accuracy Correlation')
print('SAM', round(color_sam_005.corr()[' st_acc_all'].loc[' rep_norm_all'], 2))
print('Adam:', round(color_adam_005.corr()[' st_acc_all'].loc[' rep_norm_all'], 2))
print('Rep Shift/Accuracy Correlation')
print('SAM', round(color_sam_005.corr()[' st_acc_all'].loc[' st_rep_shift_all'], 2))
print('Adam:', round(color_adam_005.corr()[' st_acc_all'].loc[' st_rep_shift_all'], 2), '\n')

print('Accuracy Comparison')
print('SAM:', round(np.mean(color_sam_005[' st_acc_all']), 2), 'vs', 'Adam:',
      round(np.mean(color_adam_005[' st_acc_all']), 2), '\n')

print('Sharpness Comparison')
print('SAM:', round(np.mean(color_sam_005[' st_sharp_all']), 2), 'vs', 'Adam:',
      round(np.mean(color_adam_005[' st_sharp_all']), 2), '\n')

print('Rep Shift Comparison')
print('SAM:', round(np.mean(color_sam_005[' st_rep_shift_all']), 2), 'vs', 'Adam:',
      round(np.mean(color_adam_005[' st_rep_shift_all']), 2), '\n')

print('Rep Norm Comparison')
print('SAM:', round(np.mean(color_sam_005[' rep_norm_all']), 2), 'vs', 'Adam:',
      round(np.mean(color_adam_005[' rep_norm_all']), 2))
# Out:
# Sharpness/Accuracy Correlation
# SAM -0.43
# Adam: -0.4
# Rep Norm/Accuracy Correlation
# SAM -0.01
# Adam: 0.8
# Rep Shift/Accuracy Correlation
# SAM -0.98
# Adam: -0.79
#
# Accuracy Comparison
# SAM: 44.9 vs Adam: 36.66
#
# Sharpness Comparison
# SAM: 0.15 vs Adam: 0.55
#
# Rep Shift Comparison
# SAM: 0.16 vs Adam: 0.35
#
# Rep Norm Comparison
# SAM: 5.2 vs Adam: 9.29

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(12,5))
axs[0].set_title('Sharpness vs. Accuracy')
axs[0].scatter(portraits_sam_005[' st_acc_all'], portraits_sam_005[' st_sharp_all'], label='SAM');
axs[0].scatter(portraits_adam_005[' st_acc_all'], portraits_adam_005[' st_sharp_all'], label='Adam');
axs[0].legend();
axs[1].set_title('Rep Norm vs. Accuracy')
axs[1].scatter(portraits_sam_005[' st_acc_all'], portraits_sam_005[' rep_norm_all'], label='SAM');
axs[1].scatter(portraits_adam_005[' st_acc_all'], portraits_adam_005[' rep_norm_all'], label='Adam');
axs[1].legend();
axs[2].set_title('Rep Shift vs. Accuracy')
axs[2].scatter(portraits_sam_005[' st_acc_all'], portraits_sam_005[' st_rep_shift_all'], label='SAM');
axs[2].scatter(portraits_adam_005[' st_acc_all'], portraits_adam_005[' st_rep_shift_all'], label='Adam');
axs[2].legend();
print('Sharpness/Accuracy Correlation')
print('SAM', round(portraits_sam_005.corr()[' st_acc_all'].loc[' st_sharp_all'], 2))
print('Adam:', round(portraits_adam_005.corr()[' st_acc_all'].loc[' st_sharp_all'], 2))
print('Rep Norm/Accuracy Correlation')
print('SAM', round(portraits_sam_005.corr()[' st_acc_all'].loc[' rep_norm_all'], 2))
print('Adam:', round(portraits_adam_005.corr()[' st_acc_all'].loc[' rep_norm_all'], 2))
print('Rep Shift/Accuracy Correlation')
print('SAM', round(portraits_sam_005.corr()[' st_acc_all'].loc[' st_rep_shift_all'], 2))
print('Adam:', round(portraits_adam_005.corr()[' st_acc_all'].loc[' st_rep_shift_all'], 2), '\n')

print('Accuracy Comparison')
print('SAM:', round(np.mean(portraits_sam_005[' st_acc_all']), 2), 'vs', 'Adam:',
      round(np.mean(portraits_adam_005[' st_acc_all']), 2), '\n')

print('Sharpness Comparison')
print('SAM:', round(np.mean(portraits_sam_005[' st_sharp_all']), 2), 'vs', 'Adam:',
      round(np.mean(portraits_adam_005[' st_sharp_all']), 2), '\n')

print('Rep Shift Comparison')
print('SAM:', round(np.mean(portraits_sam_005[' st_rep_shift_all']), 2), 'vs', 'Adam:',
      round(np.mean(portraits_adam_005[' st_rep_shift_all']), 2), '\n')

print('Rep Norm Comparison')
print('SAM:', round(np.mean(portraits_sam_005[' rep_norm_all']), 2), 'vs', 'Adam:',
      round(np.mean(portraits_adam_005[' rep_norm_all']), 2))
# Out:
# Sharpness/Accuracy Correlation
# SAM 0.28
# Adam: 0.21
# Rep Norm/Accuracy Correlation
# SAM 0.06
# Adam: -0.78
# Rep Shift/Accuracy Correlation
# SAM -0.92
# Adam: -0.43
#
# Accuracy Comparison
# SAM: 74.78 vs Adam: 77.03
#
# Sharpness Comparison
# SAM: 0.11 vs Adam: 0.07
#
# Rep Shift Comparison
# SAM: 0.08 vs Adam: 0.16
#
# Rep Norm Comparison
# SAM: 0.89 vs Adam: 1.56
